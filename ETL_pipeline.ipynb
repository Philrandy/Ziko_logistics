# %% [markdown]
# ## Importing Libraries

# %%
#Installing dependencies
# %pip install pyarrow azure-storage-blob python-dotenv
# Out:
# Requirement already satisfied: pyarrow in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (17.0.0)
# Requirement already satisfied: azure-storage-blob in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (12.23.1)
# Requirement already satisfied: python-dotenv in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from pyarrow) (2.0.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from azure-storage-blob) (1.31.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from azure-storage-blob) (43.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\iamin\appdata\roaming\python\python39\site-packages (from azure-storage-blob) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\iamin\appdata\roaming\python\python39\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\iamin\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import io
from azure.storage.blob import BlobServiceClient, BlobClient
from dotenv import load_dotenv

# %%
#Extracting data
ziko_df = pd.read_csv("ziko_logistics_data.csv")

# %%
ziko_df
# Out:
#       Transaction_ID                           Date  Customer_ID  Product_ID  \
# 0                200  2020-01-01 20:32:25.945945945         1086         536
# 1                321  2020-01-02 06:55:08.108108108         1078         523
# 2                989  2020-01-06 08:12:58.378378378         1077         535
# 3                682  2020-01-07 22:03:14.594594594         1027         546
# 4                484  2020-01-07 07:08:06.486486486         1052         556
# ...              ...                            ...          ...         ...
# 1000             250  2020-01-05 02:22:42.162162162         1095         533
# 1001             412  2020-01-07 11:27:34.054054054         1008         542
# 1002             816  2020-01-06 02:48:38.918918918         1060         511
# 1003             702  2020-01-09 08:38:55.135135135         1054         504
# 1004               4  2020-01-03 10:22:42.162162162         1018         545
#
#       Quantity  Unit_Price   Total_Cost  Discount_Rate Sales_Channel  \
# 0            3  120.436821  8265.374549           0.20        Online
# 1            6  475.724994  4047.850479            NaN      Reseller
# 2            3  146.400556          NaN           0.05        Direct
# 3            6   19.373194  8194.281993            NaN      Reseller
# 4            8  193.221313  8331.329249           0.20        Direct
# ...        ...         ...          ...            ...           ...
# 1000         5  490.760429  1138.724711            NaN      Reseller
# 1001         9  236.240910  1786.865600           0.10        Online
# 1002         6         NaN  6443.682500           0.20       Partner
# 1003         6         NaN  4814.744796            NaN        Online
# 1004         2  248.937627  1971.790456           0.20        Direct
#
#      Order_Priority  ...  Return_Reason   Payment_Type Taxable Region  \
# 0              High  ...     Wrong Item  Wire Transfer   False   West
# 1          Critical  ...        Damaged         PayPal    True  South
# 2          Critical  ...        Damaged         PayPal    True   West
# 3            Medium  ...     Wrong Item           Cash    True  South
# 4               Low  ...           Late           Cash   False  South
# ...             ...  ...            ...            ...     ...    ...
# 1000         Medium  ...        Damaged    Credit Card    True  South
# 1001         Medium  ...  Not Specified           Cash    True  South
# 1002         Medium  ...  Not Specified           Cash   False   West
# 1003         Medium  ...        Damaged           Cash    True   West
# 1004            Low  ...  Not Specified           Cash    True   East
#
#       Country Customer_Name   Customer_Phone               Customer_Email  \
# 0      Canada  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1      Mexico  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2      Canada  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3      Canada  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4      Mexico  Customer 484  +1-986-360-9109    customer.484.3@sample.com
# ...       ...           ...              ...                          ...
# 1000   Canada  Customer 250  +1-875-504-2878   customer.250.26@sample.com
# 1001      USA  Customer 412  +1-645-470-5077   customer.412.80@sample.com
# 1002   Mexico  Customer 816  +1-162-396-1771   customer.816.55@sample.com
# 1003   Canada  Customer 702  +1-130-713-1098   customer.702.30@sample.com
# 1004   Canada    Customer 4  +1-756-713-6966     customer.4.99@sample.com
#
#                      Customer_Address Product_List_Title
# 0         275 Second St, Phoenix, USA         Product 53
# 1         478 Third St, New York, USA         Product 33
# 2         843 Second St, Phoenix, USA          Product 6
# 3           153 Main St, Phoenix, USA         Product 68
# 4        264 Second St, New York, USA         Product 89
# ...                               ...                ...
# 1000        664 Main St, Chicago, USA         Product 16
# 1001       699 Third St, Houston, USA         Product 38
# 1002  453 Fourth St, Los Angeles, USA         Product 48
# 1003      438 Fourth St, Houston, USA         Product 38
# 1004       383 Park Ave, Houston, USA         Product 16
#
# [1005 rows x 25 columns]

# %%
ziko_df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Product_ID', 'Quantity',
#        'Unit_Price', 'Total_Cost', 'Discount_Rate', 'Sales_Channel',
#        'Order_Priority', 'Warehouse_Code', 'Ship_Mode', 'Delivery_Status',
#        'Customer_Satisfaction', 'Item_Returned', 'Return_Reason',
#        'Payment_Type', 'Taxable', 'Region', 'Country', 'Customer_Name',
#        'Customer_Phone', 'Customer_Email', 'Customer_Address',
#        'Product_List_Title'],
#       dtype='object')

# %% [markdown]
# ## Cleaning and Transformation of data

# %%
ziko_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         1005 non-null   int64
#  1   Date                   1005 non-null   object
#  2   Customer_ID            1005 non-null   int64
#  3   Product_ID             1005 non-null   int64
#  4   Quantity               1005 non-null   int64
#  5   Unit_Price             904 non-null    float64
#  6   Total_Cost             905 non-null    float64
#  7   Discount_Rate          714 non-null    float64
#  8   Sales_Channel          1005 non-null   object
#  9   Order_Priority         1005 non-null   object
#  10  Warehouse_Code         1005 non-null   object
#  11  Ship_Mode              1005 non-null   object
#  12  Delivery_Status        1005 non-null   object
#  13  Customer_Satisfaction  1005 non-null   object
#  14  Item_Returned          1005 non-null   bool
#  15  Return_Reason          904 non-null    object
#  16  Payment_Type           1005 non-null   object
#  17  Taxable                1005 non-null   bool
#  18  Region                 1005 non-null   object
#  19  Country                1005 non-null   object
#  20  Customer_Name          1005 non-null   object
#  21  Customer_Phone         1005 non-null   object
#  22  Customer_Email         1005 non-null   object
#  23  Customer_Address       1005 non-null   object
#  24  Product_List_Title     1005 non-null   object
# dtypes: bool(2), float64(3), int64(4), object(16)
# memory usage: 182.7+ KB

# %%
#Filling the missing parameters of the data
ziko_df.fillna({
    'Unit_Price':ziko_df['Unit_Price'].mean(),
    'Total_Cost':ziko_df['Total_Cost'].mean(),
    'Discount_Rate':0.0,
    'Return_Reason':'Unknown'

}, inplace= True)

# %%
ziko_df['Date'] =pd.to_datetime(ziko_df['Date'])

# %%
ziko_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         1005 non-null   int64
#  1   Date                   1005 non-null   datetime64[ns]
#  2   Customer_ID            1005 non-null   int64
#  3   Product_ID             1005 non-null   int64
#  4   Quantity               1005 non-null   int64
#  5   Unit_Price             1005 non-null   float64
#  6   Total_Cost             1005 non-null   float64
#  7   Discount_Rate          1005 non-null   float64
#  8   Sales_Channel          1005 non-null   object
#  9   Order_Priority         1005 non-null   object
#  10  Warehouse_Code         1005 non-null   object
#  11  Ship_Mode              1005 non-null   object
#  12  Delivery_Status        1005 non-null   object
#  13  Customer_Satisfaction  1005 non-null   object
#  14  Item_Returned          1005 non-null   bool
#  15  Return_Reason          1005 non-null   object
#  16  Payment_Type           1005 non-null   object
#  17  Taxable                1005 non-null   bool
#  18  Region                 1005 non-null   object
#  19  Country                1005 non-null   object
#  20  Customer_Name          1005 non-null   object
#  21  Customer_Phone         1005 non-null   object
#  22  Customer_Email         1005 non-null   object
#  23  Customer_Address       1005 non-null   object
#  24  Product_List_Title     1005 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(4), object(15)
# memory usage: 182.7+ KB

# %%
ziko_df.head()
# Out:
#    Transaction_ID                          Date  Customer_ID  Product_ID  \
# 0             200 2020-01-01 20:32:25.945945945         1086         536
# 1             321 2020-01-02 06:55:08.108108108         1078         523
# 2             989 2020-01-06 08:12:58.378378378         1077         535
# 3             682 2020-01-07 22:03:14.594594594         1027         546
# 4             484 2020-01-07 07:08:06.486486486         1052         556
#
#    Quantity  Unit_Price   Total_Cost  Discount_Rate Sales_Channel  \
# 0         3  120.436821  8265.374549           0.20        Online
# 1         6  475.724994  4047.850479           0.00      Reseller
# 2         3  146.400556  5096.553818           0.05        Direct
# 3         6   19.373194  8194.281993           0.00      Reseller
# 4         8  193.221313  8331.329249           0.20        Direct
#
#   Order_Priority  ... Return_Reason   Payment_Type Taxable Region  Country  \
# 0           High  ...    Wrong Item  Wire Transfer   False   West   Canada
# 1       Critical  ...       Damaged         PayPal    True  South   Mexico
# 2       Critical  ...       Damaged         PayPal    True   West   Canada
# 3         Medium  ...    Wrong Item           Cash    True  South   Canada
# 4            Low  ...          Late           Cash   False  South   Mexico
#
#   Customer_Name   Customer_Phone               Customer_Email  \
# 0  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4  Customer 484  +1-986-360-9109    customer.484.3@sample.com
#
#                Customer_Address Product_List_Title
# 0   275 Second St, Phoenix, USA         Product 53
# 1   478 Third St, New York, USA         Product 33
# 2   843 Second St, Phoenix, USA          Product 6
# 3     153 Main St, Phoenix, USA         Product 68
# 4  264 Second St, New York, USA         Product 89
#
# [5 rows x 25 columns]

# %%
ziko_df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Product_ID', 'Quantity',
#        'Unit_Price', 'Total_Cost', 'Discount_Rate', 'Sales_Channel',
#        'Order_Priority', 'Warehouse_Code', 'Ship_Mode', 'Delivery_Status',
#        'Customer_Satisfaction', 'Item_Returned', 'Return_Reason',
#        'Payment_Type', 'Taxable', 'Region', 'Country', 'Customer_Name',
#        'Customer_Phone', 'Customer_Email', 'Customer_Address',
#        'Product_List_Title'],
#       dtype='object')

# %%
#Creating the Schemas/ Customer
customer = ziko_df[['Customer_ID','Customer_Name','Customer_Phone', 'Customer_Email', 'Customer_Address']].copy().drop_duplicates().reset_index(drop=True)
customer.head()
# Out:
#    Customer_ID Customer_Name   Customer_Phone               Customer_Email  \
# 0         1086  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1         1078  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2         1077  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3         1027  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4         1052  Customer 484  +1-986-360-9109    customer.484.3@sample.com
#
#                Customer_Address
# 0   275 Second St, Phoenix, USA
# 1   478 Third St, New York, USA
# 2   843 Second St, Phoenix, USA
# 3     153 Main St, Phoenix, USA
# 4  264 Second St, New York, USA

# %%
#Product schema
product = ziko_df[['Product_ID','Product_List_Title','Quantity','Unit_Price', 'Discount_Rate',]].copy().drop_duplicates().reset_index(drop=True)

# %%
product.head()
# Out:
#    Product_ID Product_List_Title  Quantity  Unit_Price  Discount_Rate
# 0         536         Product 53         3  120.436821           0.20
# 1         523         Product 33         6  475.724994           0.00
# 2         535          Product 6         3  146.400556           0.05
# 3         546         Product 68         6   19.373194           0.00
# 4         556         Product 89         8  193.221313           0.20

# %%
#Transaction Schema
transaction =ziko_df.merge(customer, on=['Customer_ID','Customer_Name','Customer_Phone', 'Customer_Email', 'Customer_Address'], how='left') \
                    .merge(product, on=['Product_ID','Product_List_Title','Quantity','Unit_Price', 'Discount_Rate'], how ='left')\
                    [['Transaction_ID', 'Date','Total_Cost','Sales_Channel','Order_Priority',
                            'Warehouse_Code', 'Ship_Mode', 'Delivery_Status','Customer_Satisfaction', 'Item_Returned',
                            'Return_Reason','Payment_Type', 'Taxable', 'Region', 'Country']]

# %%
transaction.head()
# Out:
#    Transaction_ID                          Date   Total_Cost Sales_Channel  \
# 0             200 2020-01-01 20:32:25.945945945  8265.374549        Online
# 1             321 2020-01-02 06:55:08.108108108  4047.850479      Reseller
# 2             989 2020-01-06 08:12:58.378378378  5096.553818        Direct
# 3             682 2020-01-07 22:03:14.594594594  8194.281993      Reseller
# 4             484 2020-01-07 07:08:06.486486486  8331.329249        Direct
#
#   Order_Priority Warehouse_Code  Ship_Mode Delivery_Status  \
# 0           High           WH-3      2-Day       Cancelled
# 1       Critical           WH-1  Overnight       Backorder
# 2       Critical           WH-1  Overnight         Pending
# 3         Medium           WH-1    Express         Pending
# 4            Low           WH-2      2-Day       Delivered
#
#   Customer_Satisfaction  Item_Returned Return_Reason   Payment_Type  Taxable  \
# 0               Neutral          False    Wrong Item  Wire Transfer    False
# 1             Satisfied           True       Damaged         PayPal     True
# 2           Unsatisfied           True       Damaged         PayPal     True
# 3           Unsatisfied          False    Wrong Item           Cash     True
# 4             Satisfied           True          Late           Cash    False
#
#   Region Country
# 0   West  Canada
# 1  South  Mexico
# 2   West  Canada
# 3  South  Canada
# 4  South  Mexico

# %%
#Temporal storage of the data
customer.to_csv(r'dataset\customer.csv', index= False)
product.to_csv(r'dataset\product.csv', index= False)
transaction.to_csv(r'dataset\transaction.csv', index= False)

# %%
#Loading Data
#Azure blob connection
load_dotenv()

connect_str = os.getenv("CONNECT_STR")
blob_service_client = BlobServiceClient.from_connection_string(connect_str)

container_name = os.getenv('CONTAINER_NAME')
container_client = blob_service_client.get_container_client(container_name)

# %%
#Create a function that loads data in Azure storage as parquet file
def upload_df_to_blob_as_parquet(df, container_client, blob_name):
    buffer = io.BytesIO()
    df.to_parquet(buffer, index=False)
    buffer.seek(0)
    blob_client = container_client.get_blob_client(blob_name)
    blob_client.upload_blob(buffer, blob_type ="BlockBlob", overwrite = True)
    print(f'{blob_name} uploaded successfully')

# %%
upload_df_to_blob_as_parquet(customer, container_client, 'rawdata/customer.parquet')
upload_df_to_blob_as_parquet(product, container_client, 'rawdata/product.parquet')
upload_df_to_blob_as_parquet(transaction, container_client, 'rawdata/transaction.parquet')
# Out:
# rawdata/customer.parquet uploaded successfully
# rawdata/product.parquet uploaded successfully
# rawdata/transaction.parquet uploaded successfully
